# %% [markdown]
# # GHSI puzzle
# ## Variable transformation

# %% [markdown]
# Loading variables:

# %%
import pandas as pd
import numpy as np
from scipy.stats import boxcox
import sys
sys.path.append('./functions')
from DnRoutlier import DnRoutlier

ghsi_2019_df = pd.read_csv('data/mr_GHSI_demo_data_transf_out.csv')
ghsi_2021_df = pd.read_csv('data/GHSI_2021_large_table.csv', sep="\t")

ghsi_2019_df = ghsi_2019_df.set_index("Row")
ghsi_2021_df = ghsi_2021_df.set_index("Country")

# %% [markdown]
# Filtering by country:

# %%
common = ghsi_2019_df.index.intersection(ghsi_2021_df.index)
ghsi_2019_df = ghsi_2019_df.loc[common]
ghsi_2021_df = ghsi_2021_df.loc[common]

# Checking if the two are filtered correctly

ghsi_2019_df.index.equals(ghsi_2021_df.index)
# Out:
# True

# %% [markdown]
# Pulling names of countries and predictors into specific list for future use

# %%
country_names = ghsi_2021_df.index.tolist()
col_names = ghsi_2021_df.columns.to_list()

# %% [markdown]
# Transforming a table into a numeric matrix for further manipulation. We are preparing the GHSI 2021 data for boxcox transformation, so we can use it for PCA. The GHSI 2019 data was already cleaned and prepared by Markovic et al (2022), and will be taken as is.

# %%
ghsi_2021_matrix = ghsi_2021_df.to_numpy()


# Preparing data for boxcox transformation

ghsi_2021_matrix_transformed = np.zeros(ghsi_2021_matrix.shape)
lambdas = np.zeros(ghsi_2021_matrix.shape[1])

min_val = np.min(ghsi_2021_matrix)

if min_val <= 0:
    ghsi_2021_matrix = ghsi_2021_matrix - min_val + np.finfo(float).eps

for i in range(ghsi_2021_matrix.shape[1]):
    transformed_column, lambda_val = boxcox(ghsi_2021_matrix[:, i])
    ghsi_2021_matrix_transformed[:, i] = transformed_column
    lambdas[i] = lambda_val

# %% [markdown]
# Using DnRoutlier (Detect and Replace outlier) to replace outliers with the median for that predictor

# %%
ghsi_2021_matrix_transformed = DnRoutlier(ghsi_2021_matrix_transformed)

# %% [markdown]
# Saving the transformation into a table

# %%
ghsi_2021_table_transformed = pd.DataFrame(
    ghsi_2021_matrix_transformed,
    index=country_names,
    columns=col_names
)

ghsi_2021_table_transformed
# Out:
#               OVERALL SCORE  \
# Afghanistan        9.239996
# Andorra           10.388138
# Armenia           14.750233
# Australia         16.025246
# Austria           14.041782
# ...                     ...
# Turkey            12.993144
# Uruguay           11.394925
# Uzbekistan        11.167438
# Venezuela          7.510077
# South Africa      12.320999
#
#               1) PREVENTION OF THE EMERGENCE OR RELEASE OF PATHOGENS  \
# Afghanistan                                            7.572495
# Andorra                                               15.383090
# Armenia                                               20.249933
# Australia                                             31.656961
# Austria                                               26.888342
# ...                                                         ...
# Turkey                                                25.981757
# Uruguay                                               23.548220
# Uzbekistan                                            21.524632
# Venezuela                                              8.140242
# South Africa                                          17.723630
#
#               2) EARLY DETECTION & REPORTING FOR EPIDEMICS OF POTENTIAL INT'L CONCERN  \
# Afghanistan                                            9.829645
# Andorra                                               15.508250
# Armenia                                               24.093557
# Australia                                             27.109299
# Austria                                               16.576125
# ...                                                         ...
# Turkey                                                16.576125
# Uruguay                                                7.662603
# Uzbekistan                                             9.043068
# Venezuela                                             15.508250
# South Africa                                          19.010437
#
#               3) RAPID RESPONSE TO AND MITIGATION OF THE SPREAD OF AN EPIDEMIC  \
# Afghanistan                                            4.992588
# Andorra                                                6.162419
# Armenia                                                7.129452
# Australia                                              7.389482
# Austria                                                6.310926
# ...                                                         ...
# Turkey                                                 5.965761
# Uruguay                                                6.041667
# Uzbekistan                                             5.355757
# Venezuela                                              5.075957
# South Africa                                           7.408425
#
#               4) SUFFICIENT & ROBUST HEALTH SECTOR TO TREAT THE SICK & PROTECT HEALTH WORKERS  \
# Afghanistan                                           12.046882
# Andorra                                                8.654353
# Armenia                                               25.165138
# Australia                                             28.497672
# Austria                                               23.573333
# ...                                                         ...
# Turkey                                                23.539768
# Uruguay                                               17.321488
# Uzbekistan                                            15.022159
# Venezuela                                              9.903073
# South Africa                                          14.587601
#
#               5) COMMITMENTS TO IMPROVING NATIONAL CAPACITY, FINANCING AND ADHERENCE TO NORMS  \
# Afghanistan                                           74.102016
# Andorra                                               51.091233
# Armenia                                               71.870169
# Australia                                             89.037839
# Austria                                               78.050616
# ...                                                         ...
# Turkey                                                72.526158
# Uruguay                                               39.237939
# Uzbekistan                                            76.601333
# Venezuela                                             34.579098
# South Africa                                          50.962800
#
#               6) OVERALL RISK ENVIRONMENT AND COUNTRY VULNERABILITY TO BIOLOGICAL THREATS
# Afghanistan                                           39.253817
# Andorra                                              111.021456
# Armenia                                               62.018425
# Australia                                            104.182236
# Austria                                              121.271983
# ...                                                         ...
# Turkey                                                76.056147
# Uruguay                                              100.550379
# Uzbekistan                                            70.323656
# Venezuela                                             43.592263
# South Africa                                          77.975464
#
# [85 rows x 7 columns]

# %% [markdown]
# Saving the rearanged 2019 data, and the transformed 2021 data into CSVs for futher use.

# %%
ghsi_2019_df.to_csv("data/ghsi_2019_rearanged.csv")
ghsi_2021_table_transformed.to_csv("data/ghsi_2021_transformed.csv")
